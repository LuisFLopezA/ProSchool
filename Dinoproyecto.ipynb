# %% [markdown]
# # Clasificador de imágenes de Dinosaurio
#
# ## Estimación Optima
#
# ### Francisco Javier Gonzalez Lazlade
# ### Luis Francisco Lopez Arnaud

# %% [markdown]
# ## Dinosaurios a clasificar
# *   Tiranosaurio Rex
# *   Velociraptor
# *   Triceratops
# *   Brontosaurio
# *   Estegosaurio

# %% [markdown]
# ### Creación del set de datos

# %%
import os
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#Crear las carpetas para subir las imagenes
# !mkdir Tiranosaurio
# !mkdir Velociraptor
# !mkdir Triceratops
# !mkdir Brontosaurio
# !mkdir Estegosaurio
# Out:
# A subdirectory or file Tiranosaurio already exists.
# A subdirectory or file Velociraptor already exists.
# A subdirectory or file Triceratops already exists.
# A subdirectory or file Brontosaurio already exists.
# A subdirectory or file Estegosaurio already exists.

# %%
#Entrar en cada carpeta y descomprimir el archivo zip
# %cd Tiranosaurio
# !unzip Tiranosaurio.zip
# %cd ..

# %cd Velociraptor
# !unzip Velociraptor.zip
# %cd ..

# %cd Triceratops
# !unzip Triceratops.zip
# %cd ..

# %cd Brontosaurio
# !unzip Brontosaurio.zip
# %cd ..

# %cd Estegosaurio
# !unzip Estegosaurio.zip
# %cd ..

# %%
#Borrar los archivo ZIP para que no queden como basura
# !rm -rf /content/Tiranosaurio/Tiranosaurio.zip
# !rm -rf /content/Velociraptor/Velociraptor.zip
# !rm -rf /content/Triceratops/Triceratops.zip
# !rm -rf /content/Brontosaurio/Brontosaurio.zip
# !rm -rf /content/Estegosaurio/Estegosaurio.zip

# %%
# !pip install tensorflow
# Out:
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/e4/14/d795bb156f8cc10eb1dcfe1332b7dbb8405b634688980aa9be8f885cc888/tensorflow-2.16.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.16.1 from https://files.pythonhosted.org/packages/e0/36/6278e4e7e69a90c00e0f82944d8f2713dd85a69d1add455d9e50446837ab/tensorflow_intel-2.16.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for astunparse>=1.6.0 from https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl.metadata
# ...

# %%
#Mostrar cuantas imagenes tengo de cada categoria
# !ls /content/Tiranosaurio | wc -l
# !ls /content/Velociraptor | wc -l
# !ls /content/Triceratops | wc -l
# !ls /content/Brontosaurio | wc -l
# !ls /content/Estegosaurio | wc -l

# %%
#Mostrar algunas imagenes con pyplot

plt.figure(figsize=(15,15))

carpeta = '/content/Tiranosaurio'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
#Crear carpetas separadas para hacer el set de datos

# !mkdir dataset
# !mkdir dataset/Tiranosaurio
# !mkdir dataset/Velociraptor
# !mkdir dataset/Triceratops
# !mkdir dataset/Brontosaurio
# !mkdir dataset/Estegosaurio
# Out:
# The syntax of the command is incorrect.
# The syntax of the command is incorrect.
# The syntax of the command is incorrect.
# The syntax of the command is incorrect.
# The syntax of the command is incorrect.

# %%
#Copiar imagenes que subimos a carpetas del dataset
#Limitar para que todos tengan la misma cantidad de imagenes
#maximo 130

carpeta_fuente = '/content/Velociraptor'
carpeta_destino = '/content/dataset/Velociraptor'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 130:
    if os.path.isfile(carpeta_fuente + '/' + nombreimg):
      #Copia de la carpeta fuente a la destino
      shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '/content/Triceratops'
carpeta_destino = '/content/dataset/Triceratops'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 130:
    if os.path.isfile(carpeta_fuente + '/' + nombreimg):
      #Copia de la carpeta fuente a la destino
      shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '/content/Brontosaurio'
carpeta_destino = '/content/dataset/Brontosaurio'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 130:
    if os.path.isfile(carpeta_fuente + '/' + nombreimg):
      #Copia de la carpeta fuente a la destino
      shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '/content/Estegosaurio'
carpeta_destino = '/content/dataset/Estegosaurio'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 130:
    if os.path.isfile(carpeta_fuente + '/' + nombreimg):
      #Copia de la carpeta fuente a la destino
      shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
carpeta_fuente = '/content/Tiranosaurio'
carpeta_destino = '/content/dataset/Tiranosaurio'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 130:
    if os.path.isfile(carpeta_fuente + '/' + nombreimg):
      #Copia de la carpeta fuente a la destino
      shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Mostrar cuantas imagenes tengo de cada categoria en el dataset
# !ls /content/dataset/Tiranosaurio | wc -l
# !ls /content/dataset/Velociraptor | wc -l
# !ls /content/dataset/Triceratops | wc -l
# !ls /content/dataset/Brontosaurio | wc -l
# !ls /content/dataset/Estegosaurio | wc -l

# %%
#Aumento de datos con ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

#Crear el dataset generador que hace imagenes con transformaciones
datagen = ImageDataGenerator(
    rescale=1. / 255,  # Escalar de 0 a 1 en lugar de 255
    rotation_range = 30,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    shear_range = 15,
    zoom_range = [0.5, 1.5],
    validation_split=0.2 #20% para pruebas
)

#Generadores para sets de entrenamiento y pruebas
# Se pide que sea estandarizado a 224x224
data_gen_entrenamiento = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')

#Imprimir 10 imagenes del generador de entrenamiento
for imagen, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(imagen[i])
  break
plt.show()

# %% [markdown]
# ### Creación de la red neuronal

# %%
# Comenzamos a crear la red neuronal en tensorflow
import tensorflow as tf
# Te permite conectarte a tensorflow hub
import tensorflow_hub as hub

url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
# Tamaño y clases a considerar de las imagenes
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))

# %%
#Congelar el modelo descargado
mobilenetv2.trainable = False

# %%
# Creamos modelo con 5 capas y funcion de activación softmax
modelo = tf.keras.Sequential([
    mobilenetv2,
    tf.keras.layers.Dense(5, activation='softmax')
])

# %%
modelo.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer_2 (KerasLayer)  (None, 1280)              2257984
#
#  dense_3 (Dense)             (None, 5)                 6405
#
# ...
# Total params: 2264389 (8.64 MB)
# Trainable params: 6405 (25.02 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
# Compilar el modelo para diseñar su estructura
modelo.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#Entrenar el modelo para obtener los parametros óptimos
EPOCAS = 10

historial = modelo.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 43s 3s/step - loss: 1.6872 - accuracy: 0.2899 - val_loss: 1.5553 - val_accuracy: 0.2957
# Epoch 2/10
# 15/15 [==============================] - 38s 3s/step - loss: 1.2713 - accuracy: 0.4622 - val_loss: 1.2672 - val_accuracy: 0.4609
# Epoch 3/10
# 15/15 [==============================] - 35s 2s/step - loss: 1.0323 - accuracy: 0.6008 - val_loss: 1.1989 - val_accuracy: 0.5304
# Epoch 4/10
# 15/15 [==============================] - 37s 2s/step - loss: 0.9303 - accuracy: 0.6345 - val_loss: 1.0597 - val_accuracy: 0.6435
# Epoch 5/10
# 15/15 [==============================] - 37s 2s/step - loss: 0.8556 - accuracy: 0.6765 - val_loss: 1.0652 - val_accuracy: 0.5913
# Epoch 6/10
# 15/15 [==============================] - 37s 2s/step - loss: 0.7449 - accuracy: 0.7143 - val_loss: 0.9159 - val_accuracy: 0.6870
# Epoch 7/10
# ...

# %%
#Graficas de precisión
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(10)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precision Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Pruebas')
plt.legend(loc='lower right')
plt.title('Precisión de entrenamiento y pruebas')

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Pérdida de entrenamiento')
plt.plot(rango_epocas, val_loss, label='Pérdida de pruebas')
plt.legend(loc='upper right')
plt.title('Pérdida de entrenamiento y pruebas')
plt.show()

# %%
# Categorizar una imagen de internet
from PIL import Image
import requests
from io import BytesIO
import cv2

def categorizar(url):
  respuesta = requests.get(url)
  img = Image.open(BytesIO(respuesta.content))
  img = np.array(img).astype(float)/255

  img = cv2.resize(img, (224,224))
  prediccion = modelo.predict(img.reshape(-1, 224, 224, 3))
  return np.argmax(prediccion[0], axis=-1)

# %%
#0 = Brontosaurio, 1 = Estegosaurio, 2 = Tiranosaurio, 3 = Triceratops, 4 = Velociraptor
url = 'https://static.vecteezy.com/system/resources/previews/016/556/640/non_2x/cartoon-dinosaur-stegosaurus-on-white-background-vector.jpg' #debe ser 1
prediccion = categorizar (url)
print(prediccion)
# Out:
# 1/1 [==============================] - 0s 163ms/step
# 1
